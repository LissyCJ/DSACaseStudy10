# %% [markdown]
# # Case Study on Probability for Data Science

# %% [markdown]
# ## 1. Load the mashroom dataset into python environment

# %%
## Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
## Load data from mashrooms.csv file to data set mashroom_data
mashroom_data=pd.read_csv("D:\python\CaseStudy10\mushrooms.csv")
## Show first five rows in the titanic data set
mashroom_data.head(5)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# ## 2 . Check the basic details of the mashrooms dataset

# %%
## Display the shape - total number of rows and columns in the mashrooms dataset
mashroom_data.shape
# Out:
# (8124, 23)

# %% [markdown]
# Our dataset has 8124 rows and 23 columns in total

# %%
## Display the columns header and data type specifications etc-This will give the information about the mashroom data set. ie. information about the mashroom DataFrame including the index dtype and column dtypes, non-null values and memory usage.
print("Summary of the basic information about mashroom DataFrame and its data:")
mashroom_data.info()
# Out:
# Summary of the basic information about mashroom DataFrame and its data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
# ...

# %%
## nunique() method will print the counts of unique numbers in each column
mashroom_data.nunique()
# Out:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %% [markdown]
# The mashroom dataset contain two types of mashrooms, that is edibile (e) and poisonous (p) with some features.

# %%
## Count of the unique occurrences of ‘class’ column
mashroom_data['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# There are 4208 edibile type mashrooms available in this dataset and 3916 are poisonous type.

# %%
count = mashroom_data['class'].value_counts()
plt.figure(figsize=(8,7))
sns.barplot(count.index, count.values, alpha=0.8)
plt.ylabel('Count', fontsize=12)
plt.xlabel('Class', fontsize=12)
plt.title('Number of poisonous/edible mushrooms')
plt.show()

# %%
## Check null values if any
mashroom_data.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# No null values present in the mashroom dataset.

# %%
## Calculating the statistical data of the numerical values of the mashroom data set
mashroom_data.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %% [markdown]
# describe() method will give you the statistics of the columns.
#
# count- shows the number of responses.
#
# unique -shows the number of unique categorical values.
#
# top- shows the highest-occurring categorical value.
#
# freq -shows the frequency/count of the highest-occurring categorical value.

# %%
mashroom_data.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [markdown]
# As we can see, our columns are now of type ‘object’. We can now use LabelEncoder to convert categorical values to ordinal.

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for column in mashroom_data.columns:
    mashroom_data[column] = labelencoder.fit_transform(mashroom_data[column])

# %%
mashroom_data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [markdown]
# In our dataset the column 'veil_type' has only one type that is partial and it has no significance. So we can drop the column.

# %%
mashroom_data = mashroom_data.drop(["veil-type"],axis=1)

# %%
# ploting heatmap to see the correlation between the variables
plt.figure(figsize=[19,10])
sns.heatmap(mashroom_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# In this correlation matrix “gill-color” is -0.53 and it is the least correlating variable which is the most important one for classification.

# %% [markdown]
# ## Preparing the Data

# %% [markdown]
# Setting X and y-axis and splitting the data into train and test respectively.
#
# Since we want to predict the class of the mushroom, we will drop the ‘class’ column.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
X = mashroom_data.drop(['class'], axis=1)
y = mashroom_data['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %% [markdown]
# ## Classification Methods

# %% [markdown]
# ## 1. Logistic Regression Classification

# %%
# import the class LogisticRegression from sklearn linear_model
from sklearn.linear_model import LogisticRegression
# train the model on the training set
# create an instance of the LogisticRegression class using the default parameters
logreg = LogisticRegression()
# fit the model with data
logreg.fit(X_train, y_train)
# compare actual response values (y_test) with predicted response values (y_pred)
print(metrics.accuracy_score(y_test, y_pred))

print("Test Accuracy: {}%".format(round(lr.score(X_test, y_test)*100,2)))
# Out:
# 0.9963076923076923
# Test Accuracy: 94.77%

# %%
# make predictions on the testing set
y_pred_lr = lr.predict(X_test)
print("Logistic Regression Classifier report: \n\n", classification_report(y_test, y_pred_lr))
# Out:
# Logistic Regression Classifier report:
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       843
#            1       0.94      0.95      0.95       782
#
#     accuracy                           0.95      1625
#    macro avg       0.95      0.95      0.95      1625
# weighted avg       0.95      0.95      0.95      1625

# %% [markdown]
# ## 2. Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)

# Predict Accuracy Score
y_pred = dtc.predict(X_test)
print("Train data accuracy:",accuracy_score(y_true = y_train, y_pred=dtc.predict(X_train)))
print("Test data accuracy:",accuracy_score(y_true = y_test, y_pred=y_pred))
print("Test Accuracy: {}%".format(round(dtc.score(X_test, y_test)*100, 2)))
# Out:
# Train data accuracy: 1.0
# Test data accuracy: 1.0
# Test Accuracy: 100.0%

# %%
# Once trained our data , then we can plot the tree with the plot_tree function:
from sklearn import tree
tree.plot_tree(dtc)
# Out:
# [Text(145.56521739130434, 203.85, 'X[8] <= 3.5\ngini = 0.499\nsamples = 6499\nvalue = [3365, 3134]'),
#  Text(72.78260869565217, 176.67000000000002, 'X[19] <= 3.5\ngini = 0.279\nsamples = 2644\nvalue = [443, 2201]'),
#  Text(29.11304347826087, 149.49, 'X[18] <= 1.5\ngini = 0.214\nsamples = 476\nvalue = [418, 58]'),
#  Text(14.556521739130435, 122.31, 'gini = 0.0\nsamples = 39\nvalue = [0, 39]'),
#  Text(43.66956521739131, 122.31, 'X[20] <= 0.5\ngini = 0.083\nsamples = 437\nvalue = [418, 19]'),
#  Text(29.11304347826087, 95.13, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(58.22608695652174, 95.13, 'gini = 0.0\nsamples = 418\nvalue = [418, 0]'),
#  Text(116.45217391304348, 149.49, 'X[10] <= 2.0\ngini = 0.023\nsamples = 2168\nvalue = [25, 2143]'),
#  Text(101.89565217391305, 122.31, 'X[12] <= 0.5\ngini = 0.008\nsamples = 2152\nvalue = [9, 2143]'),
#  Text(87.33913043478262, 95.13, 'X[4] <= 3.5\ngini = 0.453\nsamples = 26\nvalue = [9, 17]'),
# ...

# %% [markdown]
# ## 3. SVM Classification

# %%
from sklearn.svm import SVC
svm = SVC(random_state=42, gamma="auto")
svm.fit(X_train, y_train)
print("Test Accuracy: {}%".format(round(svm.score(X_test, y_test)*100, 2)))
# Out:
# Test Accuracy: 100.0%

# %%
y_pred_svm = svm.predict(X_test)
print("SVM Classifier report: \n\n", classification_report(y_test, y_pred_svm))
# Out:
# SVM Classifier report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       843
#            1       1.00      1.00      1.00       782
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %% [markdown]
# ## 4. Random Forest Classification

# %%
# import the class RandomForestClassifier from sklearn.ensemble
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
#Create an instance of  RandomForestClassifier
rf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
rf.fit(X_train,y_train)

# prediction on test set
y_pred=rf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
y_pred_rf = rf.predict(X_test)
print("Random Forest Classifier report: \n\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Classifier report:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       843
#            1       1.00      1.00      1.00       782
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %% [markdown]
# ## 5. KNN Classification

# %%
# import the class KNeighborsClassifier from sklearn.neighbors
from sklearn.neighbors import KNeighborsClassifier
## Creating an instance of KNeighborsClassifier with neighbours as 5
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9993846153846154

# %% [markdown]
# ## 6.  Naive Bayes Classification

# %%
from sklearn.naive_bayes import BernoulliNB 
clf = BernoulliNB()
model = clf.fit(X_train, y_train)
y_pred =clf.predict(X_test)
acc_score = accuracy_score(y_test, y_pred)
print(acc_score)
# Out:
# 0.8418461538461538

# %%
# import the class GaussianNB from sklearn.naive_bayes
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
print("Test Accuracy: {}%".format(round(nb.score(X_test, y_test)*100, 2)))
# Out:
# Test Accuracy: 92.18%

# %%
## Classification report of Naive Bayes Classifier
y_pred_nb = nb.predict(X_test)
print("Naive Bayes Classifier report: \n\n", classification_report(y_test, y_pred_nb))
# Out:
# Naive Bayes Classifier report:
#
#                precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       843
#            1       0.91      0.93      0.92       782
#
#     accuracy                           0.92      1625
#    macro avg       0.92      0.92      0.92      1625
# weighted avg       0.92      0.92      0.92      1625

# %%
cm = confusion_matrix(y_test, y_pred_nb)
x_axis_labels = ["Edible", "Poisonous"]
y_axis_labels = ["Edible", "Poisonous"]
f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Naive Bayes Classifier')
plt.show()

# %% [markdown]
# Most of the classification methods like Decision Tree Classification, Random Forest Classification and SVM shows 100% accuracy with this dataset.
